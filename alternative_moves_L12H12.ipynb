# %%
# %load_ext autoreload
# %autoreload 2

# %%
from leela_interp.core.effect_study import *
from leela_interp.core.alternative_moves import *

# %%
#device = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device("cpu")
model = Lc0sight("lc0.onnx", device=device)
# Out:
# Using device: cpu

# %%
study = EffectStudy(model, puzzlename="all", n_examples=0, alt_puzzles=True)
# Out:
# Puzzles: 52498
# Puzzles with 3 moves in principal variation: 32076
# Puzzles with different start and end squares in principal variation: 27357
# Puzzles with full PV probabilities between 0.4 and 0.6: 2658
# Puzzles that are mate in 2: 2293
# Checking double games: 100%|██████████| 2293/2293 [08:14<00:00,  4.63it/s]
# Puzzles that are double games: 32
# Puzzles with 4 distinct moves: 11
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/effect_study.py:145: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.all_effects = -torch.load(
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/effect_study.py:154: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.all_attentions = torch.load(

# %% [markdown]
# # Tree search

# %%
puzzle = study.alt_puzzles.iloc[1]
board = LeelaBoard.from_puzzle(puzzle)

# %%
correct_moves = puzzle.Moves.split()
total_moveset = {puzzle.Moves.split()[0]: {'prob': 1.0} | get_top_moves(model, board, limit=3, min_prob=0.3)}
# Out:
# 1 {'d3h7': {'prob': 0.8853151202201843}}
# 2 {'h7h6': {'prob': 0.9883930087089539, 'd3h7': {'prob': 0.8853151202201843}}}
# 1 {'c4d3': {'prob': 0.8476101756095886}}
# 2 {'c5d3': {'prob': 0.9883109927177429, 'c4d3': {'prob': 0.8476101756095886}}}
# 3 {'g6g7': {'prob': 0.5534352660179138, 'h7h6': {'prob': 0.9883930087089539, 'd3h7': {'prob': 0.8853151202201843}}}, 'g6f6': {'prob': 0.36279740929603577, 'c5d3': {'prob': 0.9883109927177429, 'c4d3': {'prob': 0.8476101756095886}}}}

# %%
display(diff_puzzles.principal_variation.iloc[:5])
diogo_get_lc0_pv_probabilities_single_batch(model, diff_puzzles.iloc[:5])
# Out:
# 54597    [a6g6, c5g1, b1f5]
# 69803    [f3d4, f4f3, h6h7]
# 79796    [f7g5, d5d4, g5f3]
# Name: principal_variation, dtype: object
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 display(diff_puzzles.principal_variation.iloc[:5])
# ----> 2 diogo_get_lc0_pv_probabilities_single_batch(model, diff_puzzles.iloc[:5])
#
# Cell In[40], line 36, in diogo_get_lc0_pv_probabilities_single_batch(model, puzzles)
#      34 if i < len(pv):
#      35     correct_move = pv[i]
# ---> 36     top_moves = model.top_moves(board, policies[j:j+3], top_k=None)
#      37     print(top_moves)
#      38     model_move = next(iter(top_moves))
#
# File ~/Pivotal/leela-interp/src/leela_interp/core/lc0.py:304, in Lc0Model.top_moves(self, board, policy, top_k)
#     301 def top_moves(
#     302     self, board: LeelaBoard, policy: torch.Tensor, top_k: int | None = 1
#     303 ) -> dict[str, float]:
# --> 304     assert policy.shape == (self.POLICY_OUTPUT_SIZE,)
#     305     legal_indices, legal_uci = self.legal_moves(board)
#     306     if top_k is None:
#
# AssertionError:

# %%
display(diff_puzzles.principal_variation.iloc[:5])
diogo_get_lc0_pv_probabilities_single_batch(model, diff_puzzles.iloc[:5])
# Out:
# 54597    [a6g6, c5g1, b1f5]
# 69803    [f3d4, f4f3, h6h7]
# 79796    [f7g5, d5d4, g5f3]
# Name: principal_variation, dtype: object
# {'a6f6': 0.42851027846336365, 'a6g6': 0.4037629961967468, 'b1f5': 0.05111701413989067, 'h3h7': 0.032180871814489365, 'd5d6': 0.005728045012801886, 'g1f1': 0.005466668866574764, 'a6c6': 0.004058551043272018, 'a6b5': 0.0035532235633581877, 'h3g3': 0.003455784171819687, 'b2b4': 0.003141419729217887, 'b1e4': 0.0028727829921990633, 'g1g6': 0.002611294388771057, 'a3a4': 0.002384771825745702, 'b1d3': 0.002362251980230212, 'b2b3': 0.0023307898081839085, 'b1a2': 0.0022952123545110226, 'h3h4': 0.0022775321267545223, 'b1c2': 0.0022463221102952957, 'f3f4': 0.002176506444811821, 'a6a5': 0.002176256151869893, 'a6a7': 0.002138863317668438, 'a6b6': 0.0021197216119617224, 'a6e6': 0.00211249478161335, 'a6a4': 0.0021107466891407967, 'g1e1': 0.002101323800161481, 'g1d1': 0.002099031815305352, 'h3h5': 0.0020979049149900675, 'g1c1': 0.0020974078215658665, 'g1g4': 0.0020902829710394144, 'g1g3': 0.0020748809911310673, 'h3h6': 0.002073464682325721, 'a6d6': 0.0020726253278553486, 'a6b7': 0.0020451454911381006, 'g1g2': 0.002044789493083954, 'a6c8': 0.0020342301577329636, 'a6a8': 0.002018851926550269, 'g1g5': 0.0019596375059336424}
# {'h6h7': 0.49854618310928345, 'f3d4': 0.43913835287094116, 'f3g5': 0.015178829431533813, 'f3e5': 0.006834298372268677, 'h2h1': 0.005922635551542044, 'h3h4': 0.003838347038254142, 'h2g1': 0.003449820913374424, 'h6h8': 0.0028498778119683266, 'h6f6': 0.0028022180777043104, 'f3e1': 0.0027766749262809753, 'h6g6': 0.0027718334458768368, 'h6h5': 0.002763094613328576, 'f3d2': 0.002752307802438736, 'a3a4': 0.002725655445829034, 'f3h4': 0.002581228967756033, 'h6h4': 0.0025630914606153965, 'f3g1': 0.002505565294995904}
# {'b6b7': 0.40383175015449524, 'f7g5': 0.4013439416885376, 'f7e5': 0.1005527600646019, 'a6b5': 0.06812455505132675, 'f7d8': 0.019083630293607712, 'f7h8': 0.0024789529852569103, 'f7d6': 0.0023707032669335604, 'f7h6': 0.0022136804182082415}
# {'c5g1': 0.6439273953437805, 'e8f8': 0.11409570276737213, 'd2d4': 0.0937863439321518, 'd2b2': 0.01849687471985817, 'd2e3': 0.016052350401878357, 'd2e1': 0.015096720308065414, 'c5d4': 0.007388333324342966, 'd2h2': 0.006124898325651884, 'd2d5': 0.006091217510402203, 'd2g2': 0.003946299664676189, 'd2f2': 0.003787894966080785, 'd2f4': 0.0036156652495265007, 'd2g5': 0.00305368984118104, 'd2h6': 0.0029268795624375343, 'h7h6': 0.002891734940931201, 'd2c3': 0.0021581908222287893, 'h7h5': 0.002051096875220537, 'd2e2': 0.0019687730818986893, 'e7f7': 0.0019396239658817649, 'e7e3': 0.0018952094251289964, 'e8b8': 0.0017812005244195461, 'c4c3': 0.001780583173967898, 'e8a8': 0.0017407797276973724, 'e8c8': 0.001719051506370306, 'd2d1': 0.0016991148004308343, 'd2c1': 0.0016970783472061157, 'e8g8': 0.001686534727923572, 'b5b4': 0.0016857562586665154, 'c5d6': 0.0016644459683448076, 'd2b4': 0.0016432537231594324, 'd2c2': 0.0016212193295359612, 'e7a7': 0.0016079770866781473, 'e7e1': 0.00159832916688174, 'c5e3': 0.001592721207998693, 'c5a7': 0.0015884004533290863, 'e7d7': 0.00158703385386616, 'e7b7': 0.0015854242956265807, 'e8d8': 0.0015852005453780293, 'e7c7': 0.0015684568788856268, 'e7e5': 0.0015660019125789404, 'e7e6': 0.001544996746815741, 'c5b4': 0.0015403684228658676, 'c5b6': 0.0015222554793581367, 'e7e2': 0.0014993140939623117, 'd2d3': 0.0014879783848300576, 'd2a5': 0.001455447287298739, 'f5f4': 0.001387924188748002, 'c5f2': 0.001370259909890592, 'c5a3': 0.0013215120416134596, 'e7g7': 0.0012957564322277904, 'e7e4': 0.001280863187275827}
# {'b3b2': 0.4714306592941284, 'b3e3': 0.15884847939014435, 'f4f3': 0.1215149462223053, 'b3b1': 0.09989522397518158, 'b3b6': 0.04885974898934364, 'b3a3': 0.015172452665865421, 'b3g3': 0.013130513951182365, 'g5g4': 0.01183745265007019, 'b3d3': 0.011467129923403263, 'b3c3': 0.007869284600019455, 'a2b2': 0.004379386082291603, 'a2a3': 0.0034126960672438145, 'e7d6': 0.0030513007659465075, 'b3b7': 0.0029769386164844036, 'a2e2': 0.0027955402620136738, 'b3b5': 0.0022117982152849436, 'e7f8': 0.002199927344918251, 'b3b8': 0.0021973042748868465, 'a2a1': 0.0019591122400015593, 'b3h3': 0.00185205542948097, 'e7d8': 0.0017725005745887756, 'b3f3': 0.0017652047099545598, 'a2f2': 0.0016315763350576162, 'e7e8': 0.0016288687475025654, 'a2g2': 0.0016168480506166816, 'b3b4': 0.001586774131283164, 'a2d2': 0.0015482252929359674, 'a2c2': 0.0013880160404369235}
# {'b3c5': 0.36675697565078735, 'd5d4': 0.27439647912979126, 'e6e5': 0.2337990254163742, 'b3d4': 0.08131707459688187, 'a8b8': 0.024995988234877586, 'b3c1': 0.005175773054361343, 'b3d2': 0.00472678430378437, 'b3a5': 0.004473275505006313, 'b3a1': 0.004358608275651932}
# {'h3h7': 0.3654814660549164, 'b1f5': 0.3346159756183624, 'g6f6': 0.2027837634086609, 'd5d6': 0.025266358628869057, 'g6f5': 0.013783864676952362, 'b1e4': 0.0034048527013510466, 'b2b4': 0.0023353833239525557, 'a3a4': 0.0022511763963848352, 'g6d6': 0.0022220059763640165, 'b2b3': 0.0021738996729254723, 'b1a2': 0.0021685026586055756, 'b1c2': 0.0021096740383654833, 'b1d3': 0.0020430705044418573, 'h3h6': 0.001971628051251173, 'h3h5': 0.0019237380474805832, 'g6g8': 0.0018836908275261521, 'g6h5': 0.0018737532664090395, 'h3h4': 0.001869485597126186, 'f3f4': 0.0018621855415403843, 'g6g1': 0.0018379673128947616, 'g6g7': 0.0018235711613669991, 'g6g4': 0.0018022141885012388, 'g6h6': 0.0018019253620877862, 'g6g3': 0.0018016144167631865, 'g6c6': 0.001797047327272594, 'g6g2': 0.001784091698937118, 'g6b6': 0.0017676654970273376, 'h1g1': 0.0017626775661483407, 'g6a6': 0.0017451223684474826, 'g6e6': 0.001740219653584063, 'g6f7': 0.0017313386779278517, 'h3g3': 0.0017253768164664507, 'g6g5': 0.0017092768102884293, 'g6e8': 0.0016273537185043097, 'g6h7': 0.0015181448543444276}
# {'d4b3': 0.4431718587875366, 'h6h7': 0.3101987838745117, 'd4f5': 0.20265211164951324, 'd4c6': 0.013930685818195343, 'h2g3': 0.003729586023837328, 'h3h4': 0.0030534081161022186, 'h6h5': 0.0021465029567480087, 'h2h1': 0.0021083408500999212, 'h6h4': 0.0019832670222967863, 'h6h8': 0.0019755905959755182, 'h6g6': 0.001970678335055709, 'h6f6': 0.0019332919036969543, 'd4f3': 0.001924599171616137, 'd4b5': 0.0018937212880700827, 'a3a4': 0.0018750631716102362, 'h2g1': 0.0018403091235086322, 'd4c2': 0.0018383585847914219, 'd4e2': 0.001773760188370943}
# {'g5e4': 0.48784857988357544, 'g5e6': 0.19216054677963257, 'b6b7': 0.1792146861553192, 'g5f3': 0.10026105493307114, 'a6b5': 0.023616475984454155, 'g5h3': 0.009185601957142353, 'g5f7': 0.005006748251616955, 'g5h7': 0.0027062275912612677}
# ([[0.42851027846336365, 0.6439273953437805, 0.3654814660549164],
#   [0.49854618310928345, 0.4714306592941284, 0.4431718587875366],
#   [0.40383175015449524, 0.36675697565078735, 0.48784857988357544]],
#  [[0.4037629961967468, 0.6439273953437805, 0.3346159756183624],
#   [0.43913835287094116, 0.1215149462223053, 0.3101987838745117],
#   [0.4013439416885376, 0.27439647912979126, 0.10026105493307114]],
#  [['a6f6', 'c5g1', 'h3h7'],
#   ['h6h7', 'b3b2', 'd4b3'],
#   ['b6b7', 'b3c5', 'g5e4']],
#  [[0.25270628929138184, 0.3622598648071289, 0.3850337862968445],
#   [0.02690456248819828, 0.6844172477722168, 0.2886781096458435],
#   [0.8896704316139221, 0.10820890218019485, 0.002120703924447298]])

# %%
# different_targets_mask = puzzles["different_targets"].to_numpy().astype(bool)
# same_targets_mask = ~different_targets_mask
# print(f"Same targets: {same_targets_mask.sum()} ({same_targets_mask.mean():.2%})")
# print(
#     f"Different targets: {different_targets_mask.sum()} ({different_targets_mask.mean():.2%})"
# )

# %%
study.main_moves
# Out:
# [[['f2f1', 'g1f1', 'g3f2'], ['f2g2', 'e4g2', 'g3e3']],
#  [['d4d1', 'e8e1', 'd1e1'], ['a8e8', 'c1e3', 'd4b2']],
#  [['f6f1', 'e3e2', 'f1e2'], ['f6d4', 'c4b5', 'd4b4']],
#  [['d8d1', 'e4e1', 'd1e1'], ['f5e4', 'c1h6', 'f8f7']],
#  [['g5g8', 'f7e7', 'g8e8'], ['d8f8', 'f7f8', 'g5f6']],
#  [['d8d1', 'e2d1', 'e8e1'], ['c8b8', 'a7a1', 'd8d2']],
#  [['g6h6', 'h7h6', 'g4h4'], ['g6g7', 'h7h8', 'g7g8']]]

# %%
study.plot_examples(mask=study.alt_mask, n=7)
# Out:
# 0 ['f2f1', 'g1f1', 'g3f2'] [0.48180514574050903, 1.0, 0.9152519106864929]
# 1 ['d4d1', 'e8e1', 'd1e1'] [0.32572031021118164, 1.0, 0.850655734539032]
# 2 ['f6f1', 'e3e2', 'f1e2'] [0.3734111189842224, 1.0, 0.8744692802429199]
# 3 ['d8d1', 'e4e1', 'd1e1'] [0.48166900873184204, 1.0, 0.9235104918479919]
# 4 ['g5g8', 'f7e7', 'g8e8'] [0.3522133231163025, 1.0, 0.8198420405387878]
# 5 ['d8d1', 'e2d1', 'e8e1'] [0.35855019092559814, 1.0, 0.8372417688369751]
# 6 ['g6h6', 'h7h6', 'g4h4'] [0.4028894603252411, 1.0, 0.8989083170890808]
# Arrange(components=(Arrange(components=(IcebergBoard(board=Board('8/5pk1/8/1pR3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR b - - 0 29'), heatmap=['#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#ffd6d6', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#ff4e4e', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe'], next_moves=None, highlight=None, caption='L0, max log odds reduction: 3.82', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('8/5pk1/8/1pR3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR b - - 0 29'), heatmap=['#fffefe', '#fefeff', '#fcfcff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#f6f6ff', '#fefeff', '#fcfcff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fcfcff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fcfcff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fff8f8', '#fafaff', '#fffefe', '#fefeff', '#ffcece', '#fefeff', '#fffcfc', '#fcfcff', '#ffd6d6', '#fefeff', '#fefeff'], next_moves=None, highlight=None, caption='L6, max log odds reduction: 1.04', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('8/5pk1/8/1pR3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR b - - 0 29'), heatmap=['#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fafaff', '#fffefe', '#fcfcff', '#fffcfc', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fcfcff', '#fff8f8', '#f8f8ff', '#fffafa', '#fffefe', '#fcfcff', '#fefeff', '#fffcfc', '#ececff', '#ff7878', '#fffcfc', '#fefeff'], next_moves=None, highlight=None, caption='L8, max log odds reduction: 2.90', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('8/5pk1/8/1pR3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR b - - 0 29'), heatmap=['#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fcfcff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fcfcff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fff8f8', '#eaeaff', '#fffcfc', '#fffefe', '#fffefe', '#fffefe', '#fffcfc', '#eaeaff', '#ff0000', '#fafaff', '#fefeff'], next_moves=None, highlight=None, caption='L10, max log odds reduction: 5.51', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('8/5pk1/8/1pR3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR b - - 0 ...

# %%
fh.set()

# %%
# mate_puzzles = study.puzzles[study.puzzles["Themes"].apply(lambda x: "mateIn2" in x)]
mate_puzzles = study.puzzles[study.puzzles.principal_variation.apply(lambda x: len(x) == 3)]

# %%
len(mate_puzzles)
# Out:
# 32076

# %%
#puzzle = mate_puzzles.iloc[4]
puzzle = study.alt_puzzles.iloc[7]
#case = 'bad'
board = LeelaBoard.from_puzzle(puzzle)
correct_moves = puzzle.Moves.split()
total_moveset = {correct_moves[0]: {'prob': 1.0} | get_top_moves(model, board, limit=4, min_prob=0.1)}
plot_game_trees([(correct_moves, total_moveset)])#, filename=f"game_tree_{case}.pdf")

# %%
board.plot(show_lastmove=False)
# Out:
# IcebergBoard(board=Board('r3Rb2/2Q2pkp/1p4p1/8/3q4/P7/1P3PPP/R1B3K1 b - - 0 24'), heatmap=None, next_moves=None, highlight=None, caption=None, cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=False)

# %%
import os
import glob
import cairosvg

# Get the most recently modified SVG file from .iceberg/ directory
iceberg_dir = '.iceberg/'
svg_files = glob.glob(os.path.join(iceberg_dir, '*.svg'))
if svg_files:
    latest_svg = max(svg_files, key=os.path.getmtime)
    
    # Convert SVG to PDF
    output_pdf = f'board_{case}.pdf'
    cairosvg.svg2pdf(url=latest_svg, write_to=output_pdf)
    
    print(f"Converted {latest_svg} to {output_pdf}")
else:
    print("No SVG files found in .iceberg/ directory")
# Out:
# Converted .iceberg/4b8bc210be1d2aad1c76677af402dbb1c1ad4b25.svg to board_good.pdf

# %% [markdown]
# # Global activation patching

# %% [markdown]
# ## Residual stream

# %% [markdown]
# ## Mate in 3 examples

# %%
study.plot_examples(n=100)
# Out:
# 11 ['c7c1', 'a1c1', 'c8c1', 'e3c1', 'e8e1']
# 51 ['h4h8', 'g8h8', 'f4h6', 'h8g8', 'h6g7']
# 68 ['d3b1', 'd2b1', 'd8d1', 'f3e1', 'd1e1']
# 73 ['c7d6', 'e7d8', 'c1c8', 'd8c8', 'd6c7']
# 89 ['f5g3', 'h2g3', 'h4g3', 'a4h4', 'h8h4']
# Arrange(components=(Arrange(components=(IcebergBoard(board=Board('2r1r2k/ppq3pp/3b1p2/5Q1R/3P4/4B3/PP3PPP/R5K1 b - - 2 20'), heatmap=['#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#eaeaff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#ff0000', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L0, max log odds reduction: 6.51', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r1r2k/ppq3pp/3b1p2/5Q1R/3P4/4B3/PP3PPP/R5K1 b - - 2 20'), heatmap=['#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffafa', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fcfcff', '#fefeff', '#fffefe', '#fcfcff', '#fffefe', '#fffafa', '#f2f2ff', '#fffefe', '#ffe8e8', '#fefeff', '#ffeeee', '#ff0606', '#fefeff', '#fefeff'], next_moves=None, highlight=None, caption='L6, max log odds reduction: 6.34', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r1r2k/ppq3pp/3b1p2/5Q1R/3P4/4B3/PP3PPP/R5K1 b - - 2 20'), heatmap=['#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fcfcff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffcfc', '#fffcfc', '#ececff', '#fefeff', '#ffcccc', '#fcfcff', '#ff9292', '#ff0404', '#fffefe', '#fefeff'], next_moves=None, highlight=None, caption='L8, max log odds reduction: 6.38', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r1r2k/ppq3pp/3b1p2/5Q1R/3P4/4B3/PP3PPP/R5K1 b - - 2 20'), heatmap=['#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fcfcff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fcfcff', '#fffefe', '#fffefe', '#ececff', '#fefeff', '#ffd0d0', '#fefeff', '#ff7878', '#ff0606', '#fefeff', '#fffefe'], next_moves=None, highlight=None, caption='L10, max log odds reduction: 6.31', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r1r2k/ppq3pp/3b1p2/5Q1R/3P4/4B3/PP3P ...

# %% [markdown]
# ## Ratings

# %%
# # Store puzzle ratings in a numpy array
# puzzle_ratings = puzzles["Rating"].to_numpy()
# puzzle_ratings_all = puzzles_all["Rating"].to_numpy()
# puzzle_ratings_no_forcing = puzzles_no_forcing["Rating"].to_numpy()

# # Plot histogram of puzzle ratings
# plt.hist(puzzle_ratings, bins=30, label="Interesting")
# plt.hist(puzzle_ratings_all, bins=30, label="All")
# plt.hist(puzzle_ratings_no_forcing, bins=30, label="No forcing")
# plt.show()

study.plot_rating_histogram(filename="rating_histogram.pdf")

# %%
# result = EffectStudy.get_possibility_indices(puzzles, include_starting=False)
# result_all = EffectStudy.get_possibility_indices(puzzles_all, include_starting=False)
# result_no_forcing = EffectStudy.get_possibility_indices(puzzles_no_forcing, include_starting=False)
# result_starting = get_possibility_indices(puzzles, include_starting=True)
# result_all_starting = get_possibility_indices(puzzles_all, include_starting=True)
# result_no_forcing_starting = get_possibility_indices(puzzles_no_forcing, include_starting=True)

# # Only consider cases with more than N examples
# n_examples = 10
# good_results = {k: v for k, v in result.items() if len(v) > n_examples}
# good_results_all = {k: v for k, v in result_all.items() if len(v) > n_examples}
# good_results_no_forcing = {k: v for k, v in result_no_forcing.items() if len(v) > n_examples}
# good_results_starting = {k: v for k, v in result_starting.items() if len(v) > n_examples}
# good_results_all_starting = {k: v for k, v in result_all_starting.items() if len(v) > n_examples}
# good_results_no_forcing_starting = {k: v for k, v in result_no_forcing_starting.items() if len(v) > n_examples}

# # Order by number of elements
# good_results = {k: v for k, v in sorted(good_results.items(), key=lambda item: len(item[1]), reverse=True)}
# good_results_all = {k: v for k, v in sorted(good_results_all.items(), key=lambda item: len(item[1]), reverse=True)}
# good_results_no_forcing = {k: v for k, v in sorted(good_results_no_forcing.items(), key=lambda item: len(item[1]), reverse=True)}
# good_results_starting = {k: v for k, v in sorted(good_results_starting.items(), key=lambda item: len(item[1]), reverse=True)}
# good_results_all_starting = {k: v for k, v in sorted(good_results_all_starting.items(), key=lambda item: len(item[1]), reverse=True)}
# good_results_no_forcing_starting = {k: v for k, v in sorted(good_results_no_forcing_starting.items(), key=lambda item: len(item[1]), reverse=True)}

# len(good_results), len(good_results_all), len(good_results_no_forcing), len(good_results_starting), len(good_results_all_starting), len(good_results_no_forcing_starting)

# %%
# # Create mask to apply to puzzles, given in indices in good_results
# good_mask = np.zeros((len(good_results), len(puzzles)), dtype=bool)
# good_mask_all = np.zeros((len(good_results_all), len(puzzles_all)), dtype=bool)
# good_mask_no_forcing = np.zeros((len(good_results_no_forcing), len(puzzles_no_forcing)), dtype=bool)
# good_mask_starting = np.zeros((len(good_results_starting), len(puzzles)), dtype=bool)
# good_mask_all_starting = np.zeros((len(good_results_all_starting), len(puzzles_all)), dtype=bool)
# good_mask_no_forcing_starting = np.zeros((len(good_results_no_forcing_starting), len(puzzles_no_forcing)), dtype=bool)
# for i, (_, idx_list) in enumerate(good_results.items()):
#     good_mask[i, idx_list] = True
# for i, (_, idx_list) in enumerate(good_results_all.items()):
#     good_mask_all[i, idx_list] = True
# for i, (_, idx_list) in enumerate(good_results_no_forcing.items()):
#     good_mask_no_forcing[i, idx_list] = True
# for i, (_, idx_list) in enumerate(good_results_starting.items()):
#     good_mask_starting[i, idx_list] = True
# for i, (_, idx_list) in enumerate(good_results_all_starting.items()):
#     good_mask_all_starting[i, idx_list] = True
# for i, (_, idx_list) in enumerate(good_results_no_forcing_starting.items()):
#     good_mask_no_forcing_starting[i, idx_list] = True

# %% [markdown]
# ### Exporting interesting puzzles

# %%
{k: len(v) for k, v in study.good_results.items()}
# Out:
# {'123': 15658,
#  '112': 7065,
#  '111': 4719,
#  '122': 4634,
#  '12345': 3436,
#  '11234': 2167,
#  '12333': 1350,
#  '12344': 1296,
#  '11231': 831,
#  '12334': 751,
#  '11233': 697,
#  '11123': 619,
#  '11222': 572,
#  '12223': 514,
#  '1234567': 501,
#  '12234': 428,
#  '12222': 423,
#  '12342': 393,
#  '12233': 325,
#  '11112': 292,
#  '12332': 277,
#  '11223': 265,
#  '11122': 259,
#  '1123456': 238,
#  '11111': 195,
#  '12311': 180,
#  '1234566': 164,
#  '12314': 153,
#  '11221': 140,
#  '1234555': 135,
#  '1233456': 114}

# %% [markdown]
# # Effects

# %%
# for possibility, mask in zip(list(good_results), good_mask):
#     print(possibility)
#     try:
#         plot_rating(all_effects=all_effects, mask=mask, allowed_lengths=[3, 4, 5, 6, 7], include_starting=False)
#         plot_rating_layer(all_effects=all_effects, mask=mask, allowed_lengths=[3, 4, 5, 6, 7], include_starting=False)
#     except ValueError:
#         continue

# %%
# Display rows where the first move in principal_variation is different from full_model_moves

# %%
# Add main_moves to alt_puzzles
study.alt_puzzles["branch_1"] = [move_1 for move_1, move_2 in study.main_moves]
study.alt_puzzles["branch_2"] = [move_2 for move_1, move_2 in study.main_moves]
#study.alt_puzzles.to_pickle("interesting_puzzles_double.pkl")

# %%
with open("interesting_puzzles_double_alt_0_3_0_5.pkl", "wb") as f:
    pickle.dump(study.alt_puzzles, f)

# %%
for possibility, mask in zip(list(study.good_results), study.good_mask):
    study.plot_residual_effects(mask=mask, allowed_lengths=[5,6,7,8,9], rating_range=(0, 5000))

# %%
case_number = '5'
n_seeds = 5

SETTING_TO_PRETTY_NAME = {
    ("main", 1): "trained, 1st square",
    ("main", 2): "trained, 1st-B square",
    ("main", 3): "trained, 3rd square",
    ("main", 4): "trained, 3rd-B square",
    ("random_model", 1): "random, 1st square",
    ("random_model", 2): "random, 1st-B square",
    ("random_model", 3): "random, 3rd square",
    ("random_model", 4): "random, 3rd-B square",
}

if len(str(case_number)) == 7:
    SETTING_TO_PRETTY_NAME[("main", 7)] = "trained, 7th square"
    SETTING_TO_PRETTY_NAME[("random_model", 7)] = "random, 7th square"

def plot_probe_results(split="all"):
    fh.set(fast=False)
    plt.figure(figsize=(fh.HALF_WIDTH*1.5, 2*1.5))

    for i, setting in enumerate(["main", "random_model"]):
        for j, goal_square in enumerate(range(1, 5)):
            results = np.zeros((15, n_seeds))
            for seed in range(n_seeds):
                with open(f"results/probing_{case_number}/{split}/{seed}/{goal_square}/{setting}.pkl", "rb") as f:
                    new_results = pickle.load(f)
                    results[:, seed] = new_results["accuracies"]

            means = results.mean(-1)
            squared_seed_errors = results.var(-1) / results.shape[-1]
            # Size of the eval dataset is 30% of all puzzles
            squared_acc_errors = means * (1 - means) / (0.3 * 309)
            # 2 sigma errors
            errors = 2 * np.sqrt(squared_seed_errors + squared_acc_errors)

            max_layer = means.argmax()

            print(
                f"Max accuracy ({setting}, L{max_layer}): {means[max_layer]:.2f} +- {errors[max_layer]:.2f}"
            )
            plt.plot(
                means,
                label=SETTING_TO_PRETTY_NAME[(setting, goal_square)],
                color=fh.COLORS[2*j + i],
                linewidth=fh.LINE_WIDTH,
            )
            plt.fill_between(
                range(15),
                means - errors,
                means + errors,
                color=fh.COLORS[2*j + i],
                alpha=fh.ERROR_ALPHA,
                linewidth=0,
            )

    plt.title(f"Probing set {case_number}")
    plt.xlabel("Layer")
    plt.ylabel("Accuracy")
    plt.legend(loc="lower left")

    plt.ylim(0, 1.0)
    plt.xlim(0, 14)
    plt.gca().spines[:].set_visible(False)
    plt.gca().set_facecolor(fh.PLOT_FACE_COLOR)
    plt.grid(linestyle="--")
    plt.grid(which="minor", alpha=0.3, linestyle="--")

plot_probe_results()
fh.save(f"probing_{case_number}.pdf")
# Out:
# Max accuracy (main, L13): 0.91 +- 0.06
# Max accuracy (main, L14): 0.89 +- 0.07
# Max accuracy (main, L11): 0.62 +- 0.10
# Max accuracy (main, L13): 0.40 +- 0.10
# Max accuracy (random_model, L3): 0.46 +- 0.11
# Max accuracy (random_model, L11): 0.38 +- 0.11
# Max accuracy (random_model, L1): 0.07 +- 0.05
# Max accuracy (random_model, L0): 0.02 +- 0.03

# %%
EffectStudy.map_to_possibility_alt(*study.main_moves[0])
# Out:
# {'g6g7': '1'}
# {'g6g7': '1', 'h7h6': '2'}
# {'g6g7': '1', 'h7h6': '2', 'd3h7': '3'}
# {'g6f6': 'a'}
# {'g6f6': 'a', 'c5d3': 'b'}
# {'g6f6': 'a', 'c5d3': 'b', 'c4d3': 'c'}
# ['1', '2', '3', 'a', 'b', 'c']

# %%
 if study.alt_puzzles is not None:
     print(study.good_results.keys())
 else:
     print(study.main_moves.keys())
# Out:
# dict_keys(['123', '112', '111', '122', '12345', '11234', '12333', '12344', '11231', '12334', '11233', '11123', '11222', '12223', '1234567', '12234', '12222', '12342', '12233', '11112', '12332', '11223', '11122', '1123456', '11111', '12311', '1234566', '12314', '11221', '1234555', '1233456', '1123455', '1112345', '12211', '1222345', '123456789', '1123444', '12341', '1234445', '12213'])

# %%
study.main_moves
# Out:
# [[['g6g7', 'h7h6', 'd3h7'], ['g6f6', 'c5d3', 'c4d3']],
#  [['a4b6', 'c7b6', 'a8b7'], ['a4c5', 'c7f4', 'e7e3']],
#  [['g4h3', 'h1g2', 'g6g2'], ['g4f3', 'g1f1', 'g6d3']],
#  [['f2f1', 'g1f1', 'g3f2'], ['f2g2', 'e4g2', 'g3e3']],
#  [['a6f1', 'h3h4', 'h1h2'], ['a6c8', 'e7h4', 'h6g7']],
#  [['d4d1', 'e8e1', 'd1e1'], ['a8e8', 'c1e3', 'd4b2']],
#  [['f6f1', 'e3e2', 'f1e2'], ['f6d4', 'c4b5', 'd4b4']],
#  [['c5b3', 'a2b3', 'c7c2'], ['c7d6', 'd1d6', 'e8e7']],
#  [['d8d1', 'e4e1', 'd1e1'], ['f5e4', 'c1h6', 'f8f7']],
#  [['c6a6', 'a7b8', 'c5d7'], ['c6c7', 'a7a8', 'c7c6']],
#  [['c7d8', 'c6e8', 'd8e8'], ['c7b8', 'e7c8', 'b8c8']],
#  [['g5g8', 'f7e7', 'g8e8'], ['d8f8', 'f7f8', 'g5f6']],
#  [['d8d1', 'e2d1', 'e8e1'], ['c8b8', 'a7a1', 'd8d2']],
#  [['g6h6', 'h7h6', 'g4h4'], ['g6g7', 'h7h8', 'g7g8']]]

# %%
study.good_results
# Out:
# {'122345': [3451, 15867, 20062, 26658],
#  '112345': [2587, 44560, 47389],
#  '112334': [4375, 21897],
#  '123455': [269],
#  '123425': [6502],
#  '123456': [32264],
#  '122344': [41329],
#  '123445': [42678]}

# %%
study.puzzles.iloc[[4375, 21897]]
# Out:
#       PuzzleId                                                FEN  \
# 9324     09WQ2  2R5/5pk1/8/1pp3p1/3pQ2b/1P1P2qP/1BP2rB1/6KR w ...
# 46601    0lzSv  2r1k2r/2qn1ppp/3b4/pBn1p3/Pp2P1PP/4BP2/P1PQ4/2...
#
#                      Moves  Rating  RatingDeviation  Popularity  NbPlays  \
# 9324   c8c5 f2f1 g1f1 g3f2    1963               83          87      115
# 46601  d2d6 c5b3 c1b1 c7c2    1685               75          95    12075
#
#                                                   Themes  \
# 9324   attraction mate mateIn2 middlegame pin sacrifi...
# 46601  discoveredAttack mate mateIn2 middlegame pin q...
#
#                                GameUrl  \
# 9324   https://lichess.org/JWrw0RWl#56
# 46601  https://lichess.org/E78fsLiJ#36
#
#                                              OpeningTags principal_variation  \
# 9324                                                 NaN  [f2f1, g1f1, g3f2]
# 46601  Sicilian_Defense Sicilian_Defense_Najdorf_Vari...  [c5b3, c1b1, c7c2]
#
#                                            full_pv_probs    full_model_moves  \
# 9324      [0.48180514574050903, 1.0, 0.9152519106864929]  [f2f1, g1f1, g3f2]
# 46601  [0.5746010541915894, 0.07931384444236755, 0.86...  [c5b3, a2b3, c7c2]
#
#                                                 full_wdl  \
# 9324   [0.19895361363887787, 0.7666050791740417, 0.03...
# 46601  [0.11007799953222275, 0.2499588429927826, 0.63...
#
#                                   sparring_full_pv_probs  \
# 9324    [0.015839725732803345, 1.0, 0.40310412645339966]
# 46601  [0.0567881315946579, 0.45238038897514343, 0.30...
#
#       sparring_full_model_moves  \
# 9324         [g7h6, g1f1, g3f2]
# 46601        [c7d6, c1b2, c7c2]
#
#                                             sparring_wdl  different_targets  \
# 9324   [0.0063996990211308, 0.9716481566429138, 0.021...              False
# 46601  [0.024271631613373756, 0.6687401533126831, 0.3...               True
#
#                                            corrupted_fen
# 9324   8/5pk1/8/1p4p1/3pQ2b/1P1P2qP/1BP2rB1/1R4KR b -...
# 46601  2r1k2r/2qn1ppp/3Q4/pBn1p3/Pp2P1PP/4BP2/P1P1R3/...

# %%
study.main_moves
# Out:
# [[['g6g7', 'h7h6', 'd3h7'], ['g6f6', 'c5d3', 'c4d3']],
#  [['a4b6', 'c7b6', 'a8b7'], ['a4c5', 'c7f4', 'e7e3']],
#  [['g4h3', 'h1g2', 'g6g2'], ['g4f3', 'g1f1', 'g6d3']],
#  [['f2f1', 'g1f1', 'g3f2'], ['f2g2', 'e4g2', 'g3e3']],
#  [['a6f1', 'h3h4', 'h1h2'], ['a6c8', 'e7h4', 'h6g7']],
#  [['d4d1', 'e8e1', 'd1e1'], ['a8e8', 'c1e3', 'd4b2']],
#  [['f6f1', 'e3e2', 'f1e2'], ['f6d4', 'c4b5', 'd4b4']],
#  [['c5b3', 'a2b3', 'c7c2'], ['c7d6', 'd1d6', 'e8e7']],
#  [['d8d1', 'e4e1', 'd1e1'], ['f5e4', 'c1h6', 'f8f7']],
#  [['c6a6', 'a7b8', 'c5d7'], ['c6c7', 'a7a8', 'c7c6']],
#  [['c7d8', 'c6e8', 'd8e8'], ['c7b8', 'e7c8', 'b8c8']],
#  [['g5g8', 'f7e7', 'g8e8'], ['d8f8', 'f7f8', 'g5f6']],
#  [['d8d1', 'e2d1', 'e8e1'], ['c8b8', 'a7a1', 'd8d2']],
#  [['g6h6', 'h7h6', 'g4h4'], ['g6g7', 'h7h8', 'g7g8']]]

# %%
study.load_results()

# %%
fh.set()

# %%
[(key, len(value)) for key, value in study.good_results.items()]
# Out:
# [('123456', 22),
#  ('112345', 13),
#  ('112334', 8),
#  ('123445', 8),
#  ('123425', 7),
#  ('112344', 7),
#  ('122345', 4),
#  ('123455', 4),
#  ('123435', 2),
#  ('122334', 1)]

# %%
study.plot_residual_effects_grid(n_cols=2, allowed_lengths=[3], log=True)
# Out:
# 4
# 2
# 2
# 2
# 1

# %%
mask_index = list(study.good_results).index('123445')
mask = study.good_mask[mask_index].copy()
puzzle_case = 1
puzzle_pos = np.where(mask)[0][puzzle_case]
mask[:] = False
mask[puzzle_pos] = True
puzzle = study.puzzles[mask].iloc[0]
board = LeelaBoard.from_puzzle(puzzle)
corrupted_board = LeelaBoard.from_fen(puzzle.corrupted_fen)
correct_moves = puzzle.Moves.split()
total_moveset = {correct_moves[0]: {'prob': 1.0} | get_top_moves(model, board, limit=5, min_prob=0.05)}
total_moveset_corrupted = {correct_moves[0]: {'prob': 1.0} | get_top_moves(model, corrupted_board, limit=4, min_prob=0.05)}
plot_game_trees([(correct_moves, total_moveset)], width=12, height=3)
plot_game_trees([(correct_moves, total_moveset_corrupted)], width=12, height=3)
study.plot_examples(mask=mask, n=1)
# Out:
# 0 ['c1a1', 'a5b4', 'a1a8'] [0.36921364068984985, 0.8125475645065308, 0.9589868783950806]
# Arrange(components=(Arrange(components=(IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1P6/2R5 w - - 13 46'), heatmap=['#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#ff0000', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L0, max log odds reduction: 5.53', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1P6/2R5 w - - 13 46'), heatmap=['#fff0f0', '#fffefe', '#fffcfc', '#fffefe', '#f6f6ff', '#fffefe', '#ffd8d8', '#fefeff', '#fefeff', '#fffefe', '#fcfcff', '#fefeff', '#fefeff', '#fffefe', '#ffacac', '#fffefe', '#fffefe', '#fffefe', '#fcfcff', '#fffefe', '#fefeff', '#fefeff', '#fafaff', '#fffefe', '#fffefe', '#fcfcff', '#fefeff', '#fefeff', '#fffefe', '#fffcfc', '#fcfcff', '#fafaff', '#f6f6ff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffcfc', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fff6f6', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L6, max log odds reduction: 1.78', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1P6/2R5 w - - 13 46'), heatmap=['#fff8f8', '#fffefe', '#fcfcff', '#fffefe', '#f8f8ff', '#fefeff', '#ffbebe', '#fefeff', '#fcfcff', '#fffcfc', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#ffd2d2', '#fffefe', '#fffefe', '#fefeff', '#fcfcff', '#fffcfc', '#fefeff', '#fcfcff', '#fefeff', '#fffefe', '#fffefe', '#fffcfc', '#fefeff', '#fffefe', '#fefeff', '#fcfcff', '#fffcfc', '#fefeff', '#f4f4ff', '#fefeff', '#fefeff', '#fefeff', '#fffcfc', '#fffcfc', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fcfcff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffcfc', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fafaff', '#fefeff', '#ffe8e8', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff'], next_moves=None, highlight=None, caption='L8, max log odds reduction: 1.42', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1P6/2R5 w - - 13 46'), heatmap=['#fff4f4', '#fffefe', '#fefeff', '#fffefe', '#ececff', '#fefeff', '#ff8a8a', '#fefeff', '#fefeff', '#fffcfc', '#fffefe', '#fefeff', '#fffefe', '#fcfcff', '#ffeaea', '#fffefe', '#fffefe', '#fcfcff', '#fcfcff', '#fffefe', '#fffefe', '#fefeff', '#fffcfc', '#fefeff', '#fffefe', '#ffecec', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fcfcff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffcfc', '#fefeff', '#fafaff', '#fefeff', '#fefeff', '#fefeff', '#fcfcff', '#fefeff', '#ffe2e2', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff'], next_moves=None, highlight=None, caption='L10, max log odds reduction: 2.53', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1 ...

# %%
study.plot_attention(puzzle_pos, mask_index)

# %%
attribution = attention_attribution(
    [board], layer=12, head=12, model=model, return_pt=True
)[0]
values, colors = top_k_attributions(attribution, board, k=5)
print(values)
board.plot(arrows=colors, show_lastmove=False)
# Out:
# {'a8b4': 0.0099791893735528, 'a5c8': 0.0031557639595121145, 'b4g3': 0.002942137885838747, 'b4a8': 0.0026397882029414177, 'b2a8': 0.002550692530348897}
# IcebergBoard(board=Board('r7/6p1/4p3/b2pPk1p/1B1P1PpP/1p1K2P1/1P6/2R5 w - - 13 46'), heatmap=None, next_moves=None, highlight=None, caption=None, cmap='YlOrRd', mappable=None, zero_center=False, arrows={'a8b4': '#ff0000cc', 'a5c8': '#ffaeaecc', 'b4g3': '#ffb4b4cc', 'b4a8': '#ffbcbccc', 'b2a8': '#ffbebecc'}, attn_map=None, show_lastmove=False)

# %%
from leela_interp.tools.attention import attention_attribution, top_k_attributions
from leela_interp.tools.patching import activation_patch

# %%
study.all_attentions[mask].shape
# Out:
# torch.Size([1, 15, 24])

# %%
diogo_third_to_first_vs_other_ablations(model, board, puzzle, 12, 12)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.83it/s]
# (12, 12) [0]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# (tensor([0.3869]), tensor([-0.1667]))

# %%
def diogo_third_to_first_vs_other_ablations(model, board, puzzle, layer, head):
    first_target_square = puzzle.principal_variation[0][2:4]
    third_target_square = puzzle.principal_variation[2][2:4]
    first_target_index = board.sq2idx(first_target_square)
    third_target_index = board.sq2idx(third_target_square)

    def _third_to_first_ablate(location, model, batch_indices):
        layer, head = location
        print(location, batch_indices)
        model.attention_scores(layer).output[
            torch.arange(len(batch_indices)),
            head,
            first_target_index,
            third_target_index,
        ] = 0

    def _other_ablate(location, model, batch_indices):
        layer, head = location
        other_mask = torch.ones(
            len(batch_indices), 64, 64, dtype=torch.bool, device="cpu"
        )
        other_mask[
            torch.arange(len(batch_indices)),
            first_target_index,
            third_target_index,
        ] = False
        model.attention_scores(layer).output[:, head][other_mask] = 0

    third_to_first_effects = -patching.patch(
        patching_func=_third_to_first_ablate,
        locations=[(layer, head)],
        model=model,
        boards=[board],
        batch_size=1,
        pbar="batch",
    )
    other_effects = -patching.patch(
        patching_func=_other_ablate,
        locations=[(layer, head)],
        model=model,
        boards=[board],
        batch_size=1,
        pbar="batch",
    )

    return third_to_first_effects.squeeze(-1), other_effects.squeeze(-1)

# %%
from leela_interp.tools import patching

# %%
# Initialize an empty list to store results for each key
results = []

# Iterate through each key in study.good_results
for key in study.good_results.keys():
    # Get the puzzles for the current key
    key_puzzles = study.puzzles.iloc[study.good_results[key]]
    ind = np.arange(len(study.alt_puzzles))[study.alt_puzzles.index.isin(key_puzzles.index)]
    
    # Get the corresponding main moves for the puzzles in study.alt_puzzles
    key_main_moves = [study.main_moves[i] for i in ind]
    
    # Compare principal variations with main moves
    key_result = [
        puzzle.principal_variation == main_move[0]
        for (_, puzzle), main_move in zip(key_puzzles.iterrows(), key_main_moves)
    ]
    
    results.append(key_result)

# results now contains the comparison for each key
[(sum(result), len(result)) for result in results]
# Out:
# [(88, 93),
#  (45, 46),
#  (40, 42),
#  (27, 28),
#  (28, 28),
#  (26, 27),
#  (17, 17),
#  (10, 10),
#  (7, 7),
#  (6, 6),
#  (2, 2),
#  (2, 2),
#  (1, 1)]

# %%
[[get_top_moves(model, LeelaBoard.from_puzzle(puzzle), limit=1, min_prob=0.3) for _, puzzle in study.puzzles.iloc[study.good_results[key]].iterrows()] for key in study.good_results.keys()]
# Out:
# [[{'g4h3': {'prob': 0.5446300506591797}, 'g4f3': {'prob': 0.3424844443798065}},
#   {'a8e8': {'prob': 0.5885780453681946},
#    'd4d1': {'prob': 0.32572367787361145}},
#   {'f6d4': {'prob': 0.5152167081832886}, 'f6f1': {'prob': 0.3734111189842224}},
#   {'d8d1': {'prob': 0.4816689193248749},
#    'f5e4': {'prob': 0.3826422393321991}}],
#  [{'a4b6': {'prob': 0.5255542993545532},
#    'a4c5': {'prob': 0.34985116124153137}},
#   {'c8b8': {'prob': 0.5169634819030762}, 'd8d1': {'prob': 0.3585505187511444}},
#   {'g6h6': {'prob': 0.40288934111595154},
#    'g6g7': {'prob': 0.3197418451309204}}],
#  [{'f2f1': {'prob': 0.4818047881126404},
#    'f2g2': {'prob': 0.44594505429267883}},
#   {'c5b3': {'prob': 0.5746013522148132},
#    'c7d6': {'prob': 0.32112061977386475}}],
#  [{'g6g7': {'prob': 0.5534352660179138},
#    'g6f6': {'prob': 0.36279740929603577}}],
#  [{'a6f1': {'prob': 0.5961458683013916},
#    'a6c8': {'prob': 0.3569292724132538}}],
#  [{'c6a6': {'prob': 0.5479968786239624},
#    'c6c7': {'prob': 0.33223482966423035}}],
#  [{'c7d8': {'prob': 0.5104194283485413},
#    'c7b8': {'prob': 0.3390209376811981}}],
#  [{'g5g8': {'prob': 0.35221463441848755},
#    'd8f8': {'prob': 0.3455730378627777}}]]

# %%
study.good_results
# Out:
# {'122345': [3451, 15867, 20062, 26658],
#  '112345': [2587, 44560, 47389],
#  '112334': [4375, 21897],
#  '123455': [269],
#  '123425': [6502],
#  '123456': [32264],
#  '122344': [41329],
#  '123445': [42678]}

# %%
study.export_puzzles('1123344')

# %%
len(study.good_results['1123344'])
# Out:
# 57

# %%
# for possibility, mask in zip(list(study.good_results), study.good_mask):
#     print(possibility)
#     try:
#         #print("Easy puzzles")
#         study.plot_residual_effects(mask=mask, allowed_lengths=[5,6,7,8,9], rating_range=(0, 5000))
#         #print("Medium puzzles")
#         study.plot_residual_effects(mask=mask, allowed_lengths=[5,6,7,8,9], rating_range=(1000, 2000))
#         #print("Hard puzzles")
#         study.plot_residual_effects(mask=mask, allowed_lengths=[5,6,7,8,9], rating_range=(2000, 3000))
#     except ValueError:
#         continue

# %% [markdown]
# # Ratings

# %%
study.plot_rating_grid(allowed_lengths=[3,4,5,6,7,8,9], n_cols=4)
study.plot_rating_layer_grid(allowed_lengths=[3,4,5,6,7,8,9], n_cols=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 study.plot_rating_grid(allowed_lengths=[3,4,5,6,7,8,9], n_cols=4)
#       2 study.plot_rating_layer_grid(allowed_lengths=[3,4,5,6,7,8,9], n_cols=4)
#       3 ## Attention heads
#
# NameError: name 'study' is not defined

# %% [markdown]
# ## Attention heads

# %%
study.plot_attention_grid(allowed_lengths=[3,4,5,6,7,8,9], n_cols=4, vmax=0.73)
study.create_head_to_possibilities_dict()
study.create_head_to_possibilities_dict_with_effects()

# %%
[(key, len(study.good_results[key])) for key in study.good_results.keys()]
# Out:
# [('123456', 93),
#  ('112345', 46),
#  ('123425', 42),
#  ('112334', 28),
#  ('123455', 28),
#  ('123445', 27),
#  ('112344', 17),
#  ('122345', 10),
#  ('123435', 7),
#  ('122344', 6),
#  ('122334', 2),
#  ('123415', 2),
#  ('123452', 1)]

# %%
study.export_puzzles('112334')

# %%
# Convert the dict of 2D arrays to a 3D numpy array
keys = sorted(study.all_heads.keys())
first_array = study.all_heads[keys[0]]
num_rows, num_cols = first_array.shape
num_keys = len(keys)

all_heads_3d = np.zeros((num_keys, num_rows, num_cols))

for i, key in enumerate(keys):
    all_heads_3d[i] = study.all_heads[key]

print(f"Shape of the 3D array: {all_heads_3d.shape}")
print(f"Dimensions: {num_keys} keys x {num_rows} rows x {num_cols} columns")
# Out:
# Shape of the 3D array: (10, 15, 24)
# Dimensions: 10 keys x 15 rows x 24 columns

# %%
all_heads_mean = np.mean(all_heads_3d, axis=0)

# %%
def dict_to_latex_table_2(data_dict, all_heads_mean):
    # Get the keys and sort them
    keys = sorted(data_dict.keys())
    
    # Get the shape of the first array to determine the number of columns
    first_array = data_dict[keys[0]]
    num_rows, num_cols = first_array.shape
    
    # Flatten the all_heads_mean array and get indices of top 10 values
    flat_indices = np.argsort(all_heads_mean.flatten())[-10:]
    
    # Convert flat indices to 2D indices
    columns_to_include = [(idx // num_cols, idx % num_cols) for idx in flat_indices[::-1]]
    
    # Start the LaTeX table
    latex_table = "\\begin{tabular}{l|" + "c" * len(columns_to_include) + "}\n"
    latex_table += "Key & " + " & ".join([f"L{i}H{j}" for i, j in columns_to_include]) + " \\\\\n"
    latex_table += "\\hline\n"
    
    # Add data rows
    for key in keys:
        array = np.nan_to_num(data_dict[key])
        row_data = []
        for i, j in columns_to_include:
            value = array[i, j]
            if abs(value) > 0.3:
                row_data.append(f"\\textbf{{{value:.2f}}}")
            elif abs(value) < 0.1:
                row_data.append(f"\\textcolor{{gray}}{{{value:.2f}}}")
            else:
                row_data.append(f"{value:.2f}")
        latex_table += f"{key} & " + " & ".join(row_data) + " \\\\\n"
    
    # End the LaTeX table
    latex_table += "\\end{tabular}"
    
    return latex_table

# Example usage
latex_output_2 = dict_to_latex_table_2(study.all_heads, all_heads_mean)
print(latex_output_2)
# Out:
# \begin{tabular}{l|cccccccccc}
# Key & L12H12 & L12H17 & L7H19 & L13H3 & L5H14 & L12H6 & L10H22 & L13H12 & L14H1 & L13H18 \\
# \hline
# 111 & \textcolor{gray}{0.02} & \textcolor{gray}{0.00} & \textcolor{gray}{0.08} & \textcolor{gray}{0.03} & \textcolor{gray}{0.04} & \textcolor{gray}{0.01} & \textcolor{gray}{0.05} & \textcolor{gray}{0.02} & 0.10 & \textcolor{gray}{0.09} \\
# 112 & \textbf{0.52} & 0.16 & 0.19 & 0.16 & 0.13 & 0.15 & \textcolor{gray}{0.10} & 0.13 & 0.11 & \textcolor{gray}{0.07} \\
# 11223 & \textbf{0.63} & \textcolor{gray}{0.10} & 0.18 & 0.21 & 0.20 & 0.27 & \textcolor{gray}{0.08} & 0.27 & \textcolor{gray}{0.09} & 0.10 \\
# 11231 & \textcolor{gray}{0.09} & \textbf{0.96} & 0.16 & 0.15 & 0.18 & 0.10 & 0.14 & \textcolor{gray}{0.09} & 0.17 & \textcolor{gray}{0.04} \\
# 11233 & \textbf{0.57} & 0.24 & 0.20 & 0.15 & 0.10 & 0.11 & 0.13 & \textcolor{gray}{0.09} & 0.11 & \textcolor{gray}{0.02} \\
# 11234 & \textbf{0.50} & \textbf{0.38} & 0.21 & 0.21 & 0.15 & 0.23 & \textbf{0.32} & 0.20 & 0.16 & \textcolor{gray}{0.06} \\
# 1123456 & \textbf{0.30} & 0.18 & \textcolor{gray}{0.06} & 0.19 & \textbf{0.31} & 0.16 & 0.15 & 0.14 & 0.13 & \textcolor{gray}{0.02} \\
# 123 & 0.11 & \textcolor{gray}{0.02} & \textcolor{gray}{0.08} & \textcolor{gray}{0.08} & \textcolor{gray}{0.07} & \textcolor{gray}{0.04} & \textcolor{gray}{0.09} & \textcolor{gray}{0.05} & \textcolor{gray}{0.08} & 0.16 \\
# 12334 & 0.20 & \textcolor{gray}{0.09} & 0.15 & 0.15 & \textcolor{gray}{0.09} & \textcolor{gray}{0.08} & \textcolor{gray}{0.02} & \textcolor{gray}{0.07} & \textcolor{gray}{0.07} & 0.16 \\
# 12345 & 0.11 & \textcolor{gray}{0.03} & 0.11 & \textcolor{gray}{0.09} & \textcolor{gray}{0.07} & \textcolor{gray}{0.06} & \textcolor{gray}{0.08} & \textcolor{gray}{0.07} & \textcolor{gray}{0.05} & 0.19 \\
# \end{tabular}

# %%
# import numpy as np
# def dict_to_latex_table(data_dict):
#     # Get the keys and sort them
#     keys = sorted(data_dict.keys())
    
#     # Get the shape of the first array to determine the number of columns
#     first_array = data_dict[keys[0]]
#     num_rows, num_cols = first_array.shape
    
#     # Determine which columns to include and their maximum values
#     columns_to_include = []
#     for j in range(num_cols):
#         for i in range(num_rows):
#             if any(abs(np.nan_to_num(data_dict[key][i, j])) > 0.3 for key in keys):
#                 max_value = max(abs(np.nan_to_num(data_dict[key][i, j])) for key in keys)
#                 columns_to_include.append((i, j, max_value))
    
#     # Sort columns by their maximum value in descending order and keep only first 9
#     columns_to_include = sorted(columns_to_include, key=lambda x: x[2], reverse=True)[:9]
    
#     # Start the LaTeX table
#     latex_table = "\\begin{tabular}{l|" + "c" * len(columns_to_include) + "}\n"
#     latex_table += "Key & " + " & ".join([f"L{i}H{j}" for i, j, _ in columns_to_include]) + " \\\\\n"
#     latex_table += "\\hline\n"
    
#     # Add data rows
#     for key in keys:
#         array = np.nan_to_num(data_dict[key])
#         row_data = []
#         for i, j, _ in columns_to_include:
#             value = array[i, j]
#             if abs(value) > 0.3:
#                 row_data.append(f"\\textbf{{{value:.2f}}}")
#             elif abs(value) < 0.1:
#                 row_data.append(f"\\textcolor{{gray}}{{{value:.2f}}}")
#             else:
#                 row_data.append(f"{value:.2f}")
#         latex_table += f"{key} & " + " & ".join(row_data) + " \\\\\n"
    
#     # End the LaTeX table
#     latex_table += "\\end{tabular}"
    
#     return latex_table

# # Example usage
# latex_output = dict_to_latex_table(study.all_heads)
# print(latex_output)

# %%
# Print the results
for head, possibilities in study.head_to_possibilities.items():
    print(f"Head {head}: {len(possibilities)} possibilities")
    print(f"  {', '.join(possibilities)}")
    print()
# Out:
# Head (12, 12): 2 possibilities
#   112, 123
#
# Head (13, 4): 2 possibilities
#   111, 122
#
# Head (14, 1): 2 possibilities
#   111, 122
#
# Head (13, 18): 2 possibilities
#   123, 122
#
# Head (14, 10): 2 possibilities
#   122, 123
#
# Head (13, 3): 1 possibilities
#   112
#
# Head (7, 19): 1 possibilities
#   112
#
# Head (12, 17): 1 possibilities
#   112
#
# Head (12, 6): 1 possibilities
#   112
#
# Head (11, 13): 1 possibilities
#   111
#
# Head (11, 10): 1 possibilities
#   111
#
# Head (8, 12): 1 possibilities
#   111
#
# Head (14, 22): 1 possibilities
#   123
#
# Head (10, 22): 1 possibilities
#   123
#
# Head (6, 4): 1 possibilities
#   122

# %%
# Print the results
for head, possibilities in study.head_to_possibilities_with_effects.items():
    print(f"Head {head}:")
    for possibility, effect in possibilities:
        print(f"  {possibility}: {effect:.4f}")
    print()
# Out:
# Head (13, 4):
#   111: 0.2779
#   122: 0.1666
#
# Head (13, 18):
#   123: 0.1815
#   122: 0.1607
#
# Head (14, 10):
#   122: 0.1796
#   123: 0.1746
#
# Head (12, 12):
#   112: 0.7319
#
# Head (13, 3):
#   112: 0.1939
#
# Head (7, 19):
#   112: 0.1896
#
# Head (11, 13):
#   111: 0.3864
#
# Head (11, 10):
#   111: 0.3510
#
# Head (14, 22):
#   123: 0.1762

# %%
# (13, 3): Applies to 112 setups
# (13, 18): Applies to 123, 122 setups
# (12, 17): Applies to 11231 setups

# %% [markdown]
# # L12H17

# %%
study.export_puzzles('12344')

# %%
ablation_configs = [
    (['L5H14', 'L12H12', 'L12H17', 'L13H3', 'L13H12', 'L14H9', 'L14H11'], "11223"),
    (['L12H12', 'L12H17', 'L13H3', 'L13H18', 'L13H12', 'L7H19'], "1123344"),
    (['L12H12'], "112"),
    (['L12H12'], "123"),
    (['L12H17'], "11231"),
    (['L12H12', 'L13H3'], "11233"),
    (['L12H12', 'L13H3', 'L12H17'], "11234"),
    (['L12H12'], "1123456"),
    (['L12H12', 'L10H22'], "12223"),
    (['L12H12', 'L12H17'], "12334"),
    (['L12H12', 'L13H18'], "12344")
]

AblationStudy.plot_ablation_effects_grid(ablation_configs[:1], n_cols=2, filename="ablation_effects_grid_11223.pdf")
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/effect_study.py:852: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ablation[file_prefix] = torch.load("results/" + self.folder_name + "/" + file, map_location=self.device)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#       1 ablation_configs = [
#       2     (['L5H14', 'L12H12', 'L12H17', 'L13H3', 'L13H12', 'L14H9', 'L14H11'], "11223"),
#       3     (['L12H12', 'L12H17', 'L13H3', 'L13H18', 'L13H12', 'L7H19'], "1123344"),
#    (...)
#      12     (['L12H12', 'L13H18'], "12344")
#      13 ]
# ---> 15 AblationStudy.plot_ablation_effects_grid(ablation_configs[:1], n_cols=2, filename="ablation_effects_grid_11223.pdf")
#
# File ~/Pivotal/leela-interp/src/leela_interp/core/effect_study.py:912, in AblationStudy.plot_ablation_effects_grid(ablation_configs, n_cols, filename)
#     910     for case in cases:
#     911         ablation_study = AblationStudy(folder_name=case + "_" + puzzle_set)
# --> 912         ablation_study.plot_ablation_effects(ax=ax)
#     913     ax.set_title(f"{puzzle_set} - {', '.join(cases)}")
#     915 # Hide any unused subplots
#
# TypeError: AblationStudy.plot_ablation_effects() got an unexpected keyword argument 'ax'

# %%
ablation_configs = [
    (['L12H12'], "112334")
]

for cases, puzzle_set in ablation_configs:
    for case in cases:
        ablation_study = AblationStudy(folder_name=case + "_" + puzzle_set)
        print(puzzle_set, case)
        ablation_study.plot_ablation_effects(filename=f"ablation_effects_{case}_{puzzle_set}.pdf", puzzle_set=puzzle_set, LH=case)
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/effect_study.py:1064: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   @staticmethod
# 112334 L12H12

# %%
list(study.good_results)
# Out:
# ['112',
#  '111',
#  '11234',
#  '123',
#  '11231',
#  '11233',
#  '12345',
#  '11222',
#  '12334',
#  '11112',
#  '11123',
#  '12333',
#  '11122',
#  '122',
#  '11223',
#  '12344',
#  '1123456',
#  '11221',
#  '12342',
#  '11111',
#  '1123344',
#  '12223']

# %%
study.plot_examples(mask=study.good_mask[-7])
# Out:
# 0 ['c2a4', 'b4c3', 'a4a2', 'f6f7', 'a2f7'] [0.5920239090919495, 0.451749324798584, 0.8767738342285156, 0.6049863696098328, 0.8772741556167603]
# 0 ['c2a4', 'b4c3', 'a4a2', 'f6f7', 'a2f7'] [0.039466120302677155, 0.7535219788551331, 0.13934744894504547, 0.057812124490737915, 0.21995295584201813]
# 1 ['d6g3', 'h2h1', 'g3h4', 'f5h3', 'h4h3'] [0.9384021759033203, 1.0, 0.9300743937492371, 1.0, 0.8777098059654236]
# 1 ['d6g3', 'h2h1', 'g3h4', 'f5h3', 'h4h3'] [0.02824551984667778, 1.0, 0.6084303259849548, 1.0, 0.9214638471603394]
# 2 ['g2g4', 'h5h4', 'd6h6', 'f4h5', 'h6h5'] [0.934381902217865, 1.0, 0.9638696908950806, 1.0, 0.9636649489402771]
# 2 ['g2g4', 'h5h4', 'd6h6', 'f4h5', 'h6h5'] [0.034018658101558685, 1.0, 0.4383273124694824, 1.0, 0.7290634512901306]
# 3 ['g2g5', 'h4f4', 'g5f5', 'f4f3', 'f5f3'] [0.7100353240966797, 0.3128618001937866, 0.9383967518806458, 0.504242479801178, 0.9710922837257385]
# 3 ['g2g5', 'h4f4', 'g5f5', 'f4f3', 'f5f3'] [0.03426261618733406, 0.8016296029090881, 0.4578755497932434, 0.007954208180308342, 0.8205671310424805]
# 4 ['c5f8', 'h8h7', 'f8f4', 'b2d2', 'f4d2'] [0.5286223292350769, 1.0, 0.5684876441955566, 0.18523132801055908, 0.9836699962615967]
# 4 ['c5f8', 'h8h7', 'f8f4', 'b1e1', 'f4d2'] [0.019290242344141006, 1.0, 0.4358002245426178, 0.07381704449653625, 0.015695668756961823]
# Arrange(components=(Arrange(components=(IcebergBoard(board=Board('2r3k1/pp4p1/5q1p/8/1b1P4/2N5/bPQ1B1PP/3R2K1 w - - 0 23'), heatmap=['#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#ff0000', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L0, max log odds reduction: 3.49', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r3k1/pp4p1/5q1p/8/1b1P4/2N5/bPQ1B1PP/3R2K1 w - - 0 23'), heatmap=['#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffcfc', '#fff8f8', '#fcfcff', '#fffcfc', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#ffcece', '#fffefe', '#fffefe', '#fefeff', '#fffcfc', '#fefeff', '#fefeff', '#f8f8ff', '#fcfcff', '#fefeff', '#ffe6e6', '#fff6f6', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffafa', '#fffefe', '#fefeff', '#fffcfc', '#fefeff', '#fffcfc', '#fffefe', '#fffefe', '#fefeff', '#fefeff', '#fffcfc', '#fffcfc', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fefeff', '#fffefe', '#fffcfc', '#fffefe'], next_moves=None, highlight=None, caption='L6, max log odds reduction: 0.67', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r3k1/pp4p1/5q1p/8/1b1P4/2N5/bPQ1B1PP/3R2K1 w - - 0 23'), heatmap=['#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fff8f8', '#fff8f8', '#fffefe', '#fefeff', '#fffefe', '#fffcfc', '#fffcfc', '#ffeaea', '#fffefe', '#fffefe', '#fffcfc', '#fff8f8', '#fffefe', '#fffefe', '#fafaff', '#fefeff', '#fefeff', '#ffe6e6', '#fff8f8', '#fefeff', '#fffefe', '#fffcfc', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffcfc', '#fffcfc', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fffcfc', '#fffcfc', '#fefeff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L8, max log odds reduction: 0.35', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r3k1/pp4p1/5q1p/8/1b1P4/2N5/bPQ1B1PP/3R2K1 w - - 0 23'), heatmap=['#fefeff', '#fffefe', '#fefeff', '#fffcfc', '#fffefe', '#fefeff', '#fffefe', '#fff8f8', '#fff6f6', '#fffefe', '#fffefe', '#fffefe', '#fefeff', '#fffefe', '#fff2f2', '#fefeff', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fefeff', '#f6f6ff', '#fffefe', '#fefeff', '#ffd8d8', '#ffeeee', '#fefeff', '#fffefe', '#fff6f6', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fffcfc', '#fffefe', '#fefeff', '#fffefe', '#fffefe', '#fefeff', '#fff6f6', '#fffefe', '#fffcfc', '#fffefe', '#fffefe', '#fefeff', '#fcfcff', '#fffefe', '#fffefe', '#fffefe', '#fffcfc', '#fffefe', '#fcfcff', '#fffefe', '#fffefe', '#fffefe', '#fffefe', '#fffefe'], next_moves=None, highlight=None, caption='L10, max log odds reduction: 0.52', cmap='YlOrRd', mappable=None, zero_center=False, arrows=None, attn_map=None, show_lastmove=True), IcebergBoard(board=Board('2r3k1/pp4p1/5q1p/8/1b1P4/2N5/bPQ1B1PP/3R2 ...

# %% [markdown]
# # Probing

# %%
SETTING_TO_PRETTY_NAME = {
    "main": "Probe on trained model",
    "random_model": "Probe on random model",
}


def plot_probe_results(split="all"):
    fh.set(fast=False)
    plt.figure(figsize=(fh.HALF_WIDTH, 2))

    for i, setting in enumerate(["main", "random_model"]):
        results = np.zeros((15, 5))
        for seed in range(5):
            with open(f"results/probing/{split}/{seed}/{setting}.pkl", "rb") as f:
                new_results = pickle.load(f)
                results[:, seed] = new_results["accuracies"]

        means = results.mean(1)
        squared_seed_errors = results.var(1) / results.shape[1]
        # Size of the eval dataset is 30% of all puzzles
        squared_acc_errors = means * (1 - means) / (0.3 * len(puzzles))
        # 2 sigma errors
        errors = 2 * np.sqrt(squared_seed_errors + squared_acc_errors)

        max_layer = means.argmax()

        print(
            f"Max accuracy ({setting}, L{max_layer}): {means[max_layer]:.2f} +- {errors[max_layer]:.2f}"
        )
        plt.plot(
            means,
            label=SETTING_TO_PRETTY_NAME[setting],
            color=fh.COLORS[i],
            linewidth=fh.LINE_WIDTH,
        )
        plt.fill_between(
            range(15),
            means - errors,
            means + errors,
            color=fh.COLORS[i],
            alpha=fh.ERROR_ALPHA,
            linewidth=0,
        )

    plt.title("Third move prediction")
    plt.xlabel("Layer")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.ylim(0, 1.0)
    plt.xlim(0, 14)
    plt.gca().spines[:].set_visible(False)
    plt.gca().set_facecolor(fh.PLOT_FACE_COLOR)
    plt.grid(linestyle="--")
    plt.grid(which="minor", alpha=0.3, linestyle="--")

# %%
plot_probe_results()
fh.save("figures/probing.pdf")

# %%
plot_probe_results(split="different_targets")
fh.save(different_targets_dir / "probing.pdf")
plot_probe_results(split="same_targets")
fh.save(same_targets_dir / "probing.pdf")

# %% [markdown]
# # Piece movement heads

# %%
with open("interesting_puzzles.pkl", "rb") as f:
    puzzles = pickle.load(f)
len(puzzles)
# Out:
# 22517

# %%
knight_heads
# Out:
# [(0, 17),
#  (1, 19),
#  (3, 14),
#  (3, 15),
#  (4, 3),
#  (5, 3),
#  (5, 13),
#  (8, 5),
#  (9, 5),
#  (14, 22),
#  (2, 15),
#  (6, 0),
#  (6, 10),
#  (7, 11),
#  (8, 19),
#  (9, 4),
#  (10, 12),
#  (10, 22),
#  (11, 17),
#  (12, 19),
#  (12, 22),
#  (13, 0)]

# %%
len(knight_heads), len(bishop_heads), len(rook_heads)
# Out:
# (22, 27, 29)

# %%
# Create a matrix to hold the data
n_layers = 15
n_heads = 24
data = np.full((n_heads, n_layers), '', dtype=object)

# Fill the matrix with values for each piece type
for layer, head in knight_heads:
    data[head, layer] = 'K'
for layer, head in bishop_heads:
    data[head, layer] = 'B'
for layer, head in rook_heads:
    data[head, layer] = 'R'

# Set up the plot
plt.figure(figsize=(8, 12))

# Create the heatmap
ax = sns.heatmap(data.astype(bool).astype(int), cmap=['white', 'lightgray'], 
                 cbar=False, linewidths=0.5, linecolor='gray')

# Add text annotations
for i in range(n_heads):
    for j in range(n_layers):
        if data[i, j]:
            text_color = 'blue' if data[i, j] == 'K' else 'green' if data[i, j] == 'B' else 'red'
            ax.text(j+0.5, i+0.5, data[i, j], ha='center', va='center', color=text_color, fontweight='bold')

# Customize the plot
plt.title('Piece Movement Heads Across Layers')
plt.xlabel('Layer')
plt.ylabel('Head')

# Create a custom legend
legend_elements = [Patch(facecolor='lightgray', edgecolor='black', label='Knight (K)'),
                   Patch(facecolor='lightgray', edgecolor='black', label='Bishop (B)'),
                   Patch(facecolor='lightgray', edgecolor='black', label='Rook (R)')]
plt.legend(handles=legend_elements, loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
N = 4
patterns = torch.zeros(N, 15, 24, 64, 64, device=device)

boards = [LeelaBoard.from_puzzle(p) for _, p in puzzles.sample(N).iterrows()]

with model.trace(boards):
    for layer in range(15):
        patterns[:, layer] = model.attention_scores(layer).output.save()

# %%
query_indices = random.sample(range(64), N)
plt.figure(figsize=(fh.HALF_WIDTH, 2))
layer = 5

layer_bishop_heads = [head for _layer, head in bishop_heads if _layer == layer]
layer_knight_heads = [head for _layer, head in knight_heads if _layer == layer]
layer_rook_heads = [head for _layer, head in rook_heads if _layer == layer]

if not (layer_bishop_heads and layer_knight_heads and layer_rook_heads):
    raise ValueError("No good heads in this layer, pick a different one")

bishop_head = random.choice(layer_bishop_heads)
knight_head = random.choice(layer_knight_heads)
rook_head = random.choice(layer_rook_heads)

fh.set()

for row, (name, head) in enumerate(
    zip(["Bishop", "Knight", "Rook"], [bishop_head, knight_head, rook_head])
):
    for i in range(N):
        plt.subplot(3, N, row * N + i + 1)
        if i == 0:
            plt.ylabel(
                name,
                rotation=90,
                labelpad=10,
                verticalalignment="center",
            )
        plt.imshow(
            patterns[i, layer, head, query_indices[i], :].cpu().numpy().reshape(8, 8),
            cmap="Oranges",
        )
        plt.xticks([])
        plt.yticks([])
fh.save("figures/piece_movement_patterns.pdf")

# %%
save_dir = Path("results/piece_movement_heads")
data = torch.load(save_dir / "effects.pt", map_location=device)
effects = data["effects"]
piece_movement_mask = data["mask"]
# Out:
# /tmp/ipykernel_2770328/120337627.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(save_dir / "effects.pt", map_location=device)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[113], line 2
#       1 save_dir = Path("results/piece_movement_heads")
# ----> 2 data = torch.load(save_dir / "effects.pt", map_location=device)
#       3 effects = data["effects"]
#       4 piece_movement_mask = data["mask"]
#
# File ~/anaconda3/envs/leela/lib/python3.12/site-packages/torch/serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/leela/lib/python3.12/site-packages/torch/serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File ~/anaconda3/envs/leela/lib/python3.12/site-packages/torch/serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/piece_movement_heads/effects.pt'

# %%
def plot_piece_movement_ablation(mask=None):
    if mask is None:
        mask = slice(None)
    else:
        mask = mask[piece_movement_mask]
    data = {}
    colors = {}
    for i, name in enumerate(["Main ablation", "Other piece types", "Random square"]):
        data[name] = effects[("key", name)].squeeze().cpu().numpy()[mask]
        colors[name] = fh.COLORS[i]
    fh.set()
    fh.plot_percentiles(
        data,
        title="Piece movement head ablation",
        colors=colors,
        figsize=(fh.HALF_WIDTH, 2),
        y_lower=-1,
        tick_frequency=25,
        y_ticks=[0, 2, 4, 6, 8],
    )

# %%
plot_piece_movement_ablation()
fh.save("figures/piece_movement_ablation.pdf")

# %%
plot_piece_movement_ablation(mask=different_targets_mask)
fh.save(different_targets_dir / "piece_movement_ablation.pdf")
plot_piece_movement_ablation(mask=same_targets_mask)
fh.save(same_targets_dir / "piece_movement_ablation.pdf")

# %% [markdown]
# # Positional encodings
# These are the domain-specific positional encodings used by Leela.

# %%
plt.figure(figsize=(12, 8))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(
        model._lc0_model.initializers.onnx_initializer_4.cpu()
        .numpy()[0, i]
        .reshape(8, 8)
    )

plt.show()
