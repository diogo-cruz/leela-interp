# %%
# %load_ext autoreload
# %autoreload 2

# %%
from leela_interp.core.effect_study import *
from leela_interp.core.alternative_moves import *
from leela_interp.core.double_branch import *
from leela_interp.core.fifth_move_study import *
from leela_interp.core.general_study import *

# %%
#device = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device("cpu")
model = Lc0sight("lc0.onnx", device=device)
# Out:
# Using device: cpu

# %% [markdown]
# # Higher future move analysis

# %%
study = FifthMoveStudy(load_all=False)
#possibilities = study.get_possibility_list('n', lengths=[3])
study.plot_residual_effects('n', '112', clean_plot=True, filename="lt_residual_effects_112")
study.plot_residual_effects('n', '11223', clean_plot=True, filename="lt_residual_effects_11223")
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/general_study.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
study = FifthMoveStudy(puzzlename="pv7", load_all=False)
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/general_study.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
study.plot_residual_effects('n', '1123456', filename="lt_residual_effects_7", clean_plot=True)

# %% [markdown]
# # Ablation

# %%
from leela_interp.core.ablation_study import AblationStudy

# %%
ablation_configs = [
    (['L12H12'], "112"),
    (['L12H12'], "11223"),
    (['L12H12'], "11234"),
    (['L12H12'], "12223"),
    (['L12H17'], "11231"),
]

for cases, puzzle_set in ablation_configs:
    for case in cases:
        ablation_study = AblationStudy(folder_name=case + "_" + puzzle_set)
        print(puzzle_set, case)
        ablation_study.plot_ablation_effects(puzzle_set=puzzle_set, LH=case, filename="lt_ablation_effects_" + case + "_" + puzzle_set)
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/ablation_study.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# # Probing

# %%
from leela_interp.core.probing_study import ProbingStudy

# %%
cases = ['11234']

for case in cases:
    probing_study = ProbingStudy(case_number=case)
    print(probing_study.n_examples)
    probing_study.plot_probe_results(filename="lt_probe_results_" + case)
# Out:
# 3126

# %% [markdown]
# # Double branches

# %%
from leela_interp.core.double_branch import DoubleBranchStudy

# %%
study = DoubleBranchStudy(puzzlename="nomate2", load_all=True)
# Out:
# /home/dcruz/Pivotal/leela-interp/src/leela_interp/core/general_study.py:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.all_effects = -torch.load(
# ...

# %%
study.plot_residual_effects('b', '123425', clean_plot=True, filename="lt_residual_effects_123425")
# Out:
# 123425 4 4
