# %%
# %load_ext autoreload
# %autoreload 2

# %%
from leela_interp.core.effect_study import *
from leela_interp.core.alternative_moves import *
from leela_interp.core.double_branch import *
from leela_interp.core.fifth_move_study import *
from leela_interp.core.general_study import *
from leela_interp.core.ablation_study import AblationStudy
from leela_interp.core.probing_study import ProbingStudy
import subprocess
# Disable FutureWarning
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from leela_interp.core.double_branch import DoubleBranchStudy

# %%
import pandas as pd
with open("lichess_db_puzzle.csv", "rb") as f:
    puzzles = pd.read_csv(f)
len(puzzles)
# Out:
# 4062423

# %%
with open("puzzles/interesting_puzzles_alternate.pkl", "rb") as f:
    puzzles = pickle.load(f)
len(puzzles)
# Out:
# 609

# %%
#device = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device("cpu")
model = Lc0sight("lc0.onnx", device=device)
# Out:
# Using device: cpu

# %%
study = DoubleBranchStudy(puzzlename="nomate3", load_all=True)

# %%
len(study.puzzles)
# Out:
# 144

# %%
list(study.puzzle_sets['b'])
# Out:
# ['122345',
#  '112334',
#  '123456',
#  '112344',
#  '123445',
#  '112345',
#  '123425',
#  '122334',
#  '123455']

# %%
for case in study.puzzle_sets['b']:
    study._plot_residual_effects_extended('b', case)
# Out:
# 122345 6 6
# 112334 16 10
# 123456 29 10
# 112344 12 10
# 123445 11 10
# 112345 14 10
# 123425 16 10
# 122334 7 7
# 123455 13 10
